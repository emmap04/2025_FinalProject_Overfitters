# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression              # for simulating data
from sklearn.model_selection import train_test_split      # splitting training and test data
from sklearn.linear_model import LinearRegression         # making the linear predictor model
from sklearn.metrics import mean_squared_error, r2_score 
import pandas as pd

# %%
df = pd.read_csv('Marriage_Divorce_DB.csv')

# %%
df
# Out:
#      Age Gap  Education  Economic Similarity  Social Similarities  \
# 0   0.111633   1.915111            10.998678            76.456065
# 1   3.355384   2.957842            82.138120            48.656031
# 2   6.527365   2.772463            26.337826            59.356238
# 3   5.203075   1.729242            66.956033             5.472612
# 4   6.864962   4.370290            76.245035            26.797234
# ..       ...        ...                  ...                  ...
# 95  6.962987   4.290912             8.386214            62.291307
# 96  0.782445   3.134205            59.812318            65.977429
# 97  4.181422   1.213900            36.880983            66.255955
# 98  3.487983   1.658356            74.237358            41.293409
# 99  5.818757   3.087757            56.908983            41.398349
#
#     Cultural Similarities  Social Gap  Common Interests  \
# 0               47.847460   50.317656         88.099898
# 1               30.188517   54.114612         57.020971
# ...

# %%
# find feature with highest correlation with the Median House Value
correlation_matrix = california.corr()
best_feature = correlation_matrix["MedHouseVal"].drop("MedHouseVal").idxmax()
print("Best feature:", best_feature)  # Feature with highest correlation is MedInc

#Predict the Median House Value with the highest correlated feature
X_best = california[[best_feature]]
y = california["MedHouseVal"]

model = LinearRegression()
model.fit(X_best, y)
y_pred = model.predict(X_best)

r2_single = r2_score(y, y_pred)
print("R² using only the most correlated feature:", r2_single)
