# %%
import pandas as pd
divorce = pd.read_csv('data/Marriage_Divorce_DB.csv')

# %%
divorce.head()
# Out:
#     Age Gap  Education  Economic Similarity  Social Similarities  \
# 0  0.111633   1.915111            10.998678            76.456065
# 1  3.355384   2.957842            82.138120            48.656031
# 2  6.527365   2.772463            26.337826            59.356238
# 3  5.203075   1.729242            66.956033             5.472612
# 4  6.864962   4.370290            76.245035            26.797234
#
#    Cultural Similarities  Social Gap  Common Interests  \
# 0              47.847460   50.317656         88.099898
# 1              30.188517   54.114612         57.020971
# 2              10.340252   76.595377         80.590985
# 3               1.003407   55.071435         99.718078
# 4              93.291581   73.736241         52.896199
#
#    Religion Compatibility  No of Children from Previous Marriage  \
# 0               83.738075                               4.402822
# 1               98.408133                               4.367024
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression             
from sklearn.model_selection import train_test_split      
from sklearn.linear_model import LinearRegression         
from sklearn.metrics import mean_squared_error, r2_score

# %%
## finding the most correlated 
r_scores = {}
for col in divorce.columns[:-1]:
    x = divorce[[col]]
    y = divorce['Divorce Probability']

    model = LinearRegression()
    model.fit(x, y)

    y_pred = model.predict(x)
    r2 = r2_score(y, y_pred)
    r_scores[col] = r2
r_scores

sorted_rscore = sorted(r_scores.items(), key=lambda item: item[1], reverse=True)
sorted_rscore
# Out:
# [('Education', 0.10096304609947393),
#  ('Good Income', 0.032350278822079415),
#  ('Start Socializing with the Opposite Sex Age ', 0.027450498351666464),
#  ('Social Similarities', 0.019753750347597077),
#  ('Relationship with the Spouse Family', 0.014809950614526057),
#  ('Addiction', 0.014084791466050905),
#  ('Previous Trading', 0.01061850017065924),
#  ('Love', 0.009541642438288145),
#  ('Age Gap', 0.009418739513467278),
#  ('The Proportion of Common Genes', 0.00936481367005626),
#  ('Desire to Marry', 0.007762497543434943),
#  ('The Sense of Having Children', 0.007277918282733609),
#  ('Mental Health', 0.005029489124172559),
#  ('Independency', 0.005027235586980705),
#  ('Relation with Non-spouse Before Marriage', 0.004807796621200677),
#  ('Loyalty', 0.0041230124999136475),
#  ('Spouse Confirmed by Family', 0.00357875985483902),
#  ('Divorce in the Family of Grade 1', 0.002941171157932909),
#  ('Social Gap', 0.0028580096185232273),
#  ('Engagement Time', 0.002509267930744463),
# ...

# %%
##the 3 most correlated factor in divorce probability
x = divorce[['Education', 'Good Income', 'Start Socializing with the Opposite Sex Age ']].values.reshape(-1, 1)

# %%
y = divorce['Divorce Probability']
